# %%
import math

# %%
E = 6
N = 4



math.factorial(E+N-1)/(math.factorial(E) * math.factorial(N-1))
# Out:
# 84.0

# %%
import matplotlib.pyplot as plt
import numpy as np

T = 22
mu = -0.00267
sigma = 0.00936
S0 = 9.054
dt = 0.1
N = round(T/dt)
t = np.linspace(0, T, N)
W = np.random.standard_normal(size = N) 
W = np.cumsum(W)*np.sqrt(dt) ### standard brownian motion ###
X = (mu-0.5*sigma**2)*t + sigma*W 
S = S0*np.exp(X) ### geometric brownian motion ###
plt.plot(t, S)
plt.show()
